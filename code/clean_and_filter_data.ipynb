# %%
import pandas as pd
import numpy as np
import nltk
import os
from pathlib2 import Path
import re
import shutil
import ProjectDirectory as directory

# %%
def clean_filing(input_filename, filing_type, output_filename):
    """
    Cleans a 10-K or 10-Q filing. All arguments take strings as input
    input_filename: name of the file to be cleaned
    filing_type: either 10-K or 10-Q
    outuput_filename: name of output file
    """
    
    # open file and get rid of all lines 
    with open (input_filename, 'r') as f:
        data = f.read().replace('\n', ' ')
    
    # get text in between the appropriate 10-K tags
    search_10k = re.search("(?s)(?m)<TYPE>{}.*?(</TEXT>)".format(filing_type), data)
    try:
        data_processed = search_10k.group(0)
    
        # delete formatting text used to identify 10-K section as its not relevant
        data_processed = re.sub(pattern="((?i)<TYPE>).*?(?=<)", repl='', string=data_processed)

        # Five more formatting tags are deleted
        data_processed = re.sub(pattern="((?i)<SEQUENCE>).*?(?=<)", repl='', string=data_processed)
        data_processed = re.sub(pattern="((?i)<FILENAME>).*?(?=<)", repl='', string=data_processed)
        data_processed = re.sub(pattern="((?i)<DESCRIPTION>).*?(?=<)", repl='', string=data_processed)
        data_processed = re.sub(pattern="(?s)(?i)<head>.*?</head>", repl='', string=data_processed)
        data_processed = re.sub(pattern="(?s)(?i)<(table).*?(</table>)", repl='', string=data_processed)

        # Tags each section of the financial statement with prefix '°Item' for future analysis
        data_processed = re.sub(pattern="(?s)(?i)(?m)> +Item|>Item|^Item", repl=">Â°Item", string=data_processed, count=0)

        # Removes all HTML tags
        data_processed = re.sub(pattern="(?s)<.*?>", repl=" ", string=data_processed, count=0)

        # Replaces all Unicode strings
        data_processed = re.sub(pattern="&(.{2,6});", repl=" ", string=data_processed, count=0)

        # Replaces multiple spaces with a single space
        data_processed = re.sub(pattern="(?s) +", repl=" ", string=data_processed, count=0)

        with open(output_filename, 'w') as output:
            output.write(data_processed)
            
    except BaseException as e:
        print('{} could not be cleaned. Exception: {}'.format(input_filename, e))
        pass

# %%
def clean_all_filings():
    """Clean all filings in sec-filings directory"""
    
    project_dir = directory.get_project_dir()
    company_list = os.listdir(os.path.join(project_dir, 'sec-filings-downloaded'))  

    for company in company_list:
        company_dir = os.path.join(project_dir, 'sec-filings-downloaded', company)
        os.chdir(company_dir) # abs path to each company directory
        
        print('***Cleaning: {}***'.format(company))
        for file in os.listdir():  # iterate through all files in the respective company directory
            
            # cleaning files
            if file.startswith('cleaned'): 
                continue
            
            if file.endswith('10-K'): filing_type = '10-K'
            else: filing_type = '10-Q'
            
            if file.endswith('10-K') or file.endswith('10-Q'):
                clean_filing(input_filename=file, filing_type=filing_type, output_filename='cleaned_' + str(file))
                print('{} filing cleaned'.format(file))

# %%
def rename_10_Q_filings():
    """Rename 10Q filigns to include the quarter of the filing in the filing name"""
    
    project_dir = directory.get_project_dir()
    company_list = os.listdir(os.path.join(project_dir, 'sec-filings-downloaded'))  
    
    for company in company_list:
        company_dir = os.path.join(project_dir, 'sec-filings-downloaded', company)
        os.chdir(company_dir)
        
        print('***{}***'.format(company))
        for file in os.listdir():
            if file.startswith('cleaned_filings') or file.startswith('cleaned_Q'): 
                continue
                
            if file.startswith('cleaned') and file.endswith('10-Q'):
                get_date = file[8:18]
                get_year = file[8:12]
                get_month = int(file[13:15])

                if get_month >= 1 and get_month <= 5:
                    filing_quarter = 'Q1'
                elif get_month >= 6 and get_month <= 8:
                    filing_quarter = 'Q2'
                else:
                    filing_quarter = 'Q3'

                os.rename(file, ('cleaned_'+str(filing_quarter)+'_'+str(get_date)+'_'+'10-Q'))
                print('{} renamed'.format(file))
            
            else:
                print('{} not renamed'.format(file))

# %%
def move_10k_10q_to_folder():
    """Move filings to the appropriate folders in each company directory"""
    
    project_dir = directory.get_project_dir()
    
    company_list = os.listdir(os.path.join(project_dir, 'sec-filings-downloaded'))  

    for company in company_list:    
        # make directory of cleaned files
        cleaned_files_dir = os.path.join(project_dir, 'sec-filings-downloaded', company, 'cleaned_filings')
        if not os.path.exists(cleaned_files_dir): os.makedirs(cleaned_files_dir)
        
        company_dir = os.path.join(project_dir, 'sec-filings-downloaded', company)
        os.chdir(company_dir) # abs path to each company directory    
        
        print('***{}***'.format(company))
        for file in os.listdir():
            if file.startswith('cleaned_filings'): continue  # cleaned_filings directory
            if file.startswith('clean') and (file.endswith('10-Q') or file.endswith('10-K')):
                try:
                    shutil.move(os.path.join(company_dir, file), os.path.join(cleaned_files_dir, file))
                    print('{} moved to cleaned files folder'.format(file))
                except Exception as e:
                    os.remove(os.path.join(cleaned_files_dir, file))
                    shutil.move(os.path.join(company_dir, file), os.path.join(cleaned_files_dir, file))
                    print('{} moved to cleaned files folder'.format(file))

# %%
clean_all_filings()
# Out:
# ***Cleaning: NETFLIX INC***
# C:\Users\Jotham\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: Flags not at the start of the expression '((?i)<TYPE>).*?(?=<)'
# C:\Users\Jotham\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: Flags not at the start of the expression '((?i)<SEQUENCE>).*?(' (truncated)
# C:\Users\Jotham\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: Flags not at the start of the expression '((?i)<FILENAME>).*?(' (truncated)
# C:\Users\Jotham\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: Flags not at the start of the expression '((?i)<DESCRIPTION>).' (truncated)
# 2018-07-18_10-Q filing cleaned
# 2019-01-29_10-K filing cleaned
# 2018-01-29_10-K filing cleaned
# 2018-10-18_10-Q filing cleaned
# 2017-07-19_10-Q filing cleaned
# 2018-04-18_10-Q filing cleaned
# 2017-10-18_10-Q filing cleaned
# 2017-04-20_10-Q filing cleaned
# 2016-10-20_10-Q filing cleaned
# 2017-01-27_10-K filing cleaned
# 2016-07-19_10-Q filing cleaned
# 2016-04-20_10-Q filing cleaned
# 2015-07-17_10-Q filing cleaned

# %%
rename_10_Q_filings()

# %%
move_10k_10q_to_folder()
# Out:
# ***CORE LABORATORIES N V***
# cleaned_Q2_2018-07-27_10-Q moved to cleaned files folder
# cleaned_2019-02-11_10-K moved to cleaned files folder
# cleaned_2018-02-12_10-K moved to cleaned files folder
# cleaned_Q3_2018-10-25_10-Q moved to cleaned files folder
# cleaned_Q2_2017-07-26_10-Q moved to cleaned files folder
# cleaned_Q1_2018-04-27_10-Q moved to cleaned files folder
# cleaned_Q3_2017-10-25_10-Q moved to cleaned files folder
# cleaned_Q1_2017-04-21_10-Q moved to cleaned files folder
# cleaned_Q3_2016-10-21_10-Q moved to cleaned files folder
# cleaned_2017-02-10_10-K moved to cleaned files folder
# cleaned_Q2_2016-07-22_10-Q moved to cleaned files folder
# cleaned_Q1_2016-04-22_10-Q moved to cleaned files folder
# cleaned_Q2_2015-07-27_10-Q moved to cleaned files folder
# cleaned_Q3_2015-10-23_10-Q moved to cleaned files folder
# cleaned_2016-02-12_10-K moved to cleaned files folder
# cleaned_Q1_2015-04-29_10-Q moved to cleaned files folder
# cleaned_2015-02-17_10-K moved to cleaned files folder
# cleaned_Q2_2014-07-25_10-Q moved to cleaned files folder
# cleaned_Q3_2014-11-04_10-Q moved to cleaned files folder
# cleaned_Q1_2014-04-25_10-Q moved to cleaned files folder
# cleaned_2014-02-13_10-K moved to cleaned files folder
# ***AMAZON COM INC***
# cleaned_Q2_2018-07-27_10-Q moved to cleaned files folder
# cleaned_2019-02-01_10-K moved to cleaned files folder
# cleaned_2018-02-02_10-K moved to cleaned files folder
# cleaned_Q3_2018-10-26_10-Q moved to cleaned files folder
# cleaned_Q2_2017-07-28_10-Q moved to cleaned files folder
# cleaned_Q1_2018-04-27_10-Q moved to cleaned files folder
# cleaned_Q3_2017-10-27_10-Q moved to cleaned files folder
# cleaned_Q1_2017-04-28_10-Q moved to cleaned files folder
# cleaned_Q3_2016-10-28_10-Q moved to cleaned files folder
# cleaned_2017-02-10_10-K moved to cleaned files folder
# cleaned_Q2_2016-07-29_10-Q moved to cleaned files folder
# cleaned_Q1_2016-04-29_10-Q moved to cleaned files folder
# cleaned_Q2_2015-07-24_10-Q moved to cleaned files folder
# cleaned_Q3_2015-10-23_10-Q moved to cleaned files folder
# cleaned_2016-01-29_10-K moved to cleaned files folder
# cleaned_Q1_2015-04-24_10-Q moved to cleaned files folder
# cleaned_2015-01-30_10-K moved to cleaned files folder
# cleaned_Q2_2014-07-25_10-Q moved to cleaned files folder
# cleaned_Q3_2014-10-24_10-Q moved to cleaned files folder
# cleaned_Q1_2014-04-25_10-Q moved to cleaned files folder
# cleaned_2014-01-31_10-K moved to cleaned files folder
# ***NETFLIX INC***
# cleaned_Q2_2018-07-18_10-Q moved to cleaned files folder
# cleaned_2019-01-29_10-K moved to cleaned files folder
# cleaned_2018-01-29_10-K moved to cleaned files folder
# cleaned_Q3_2018-10-18_10-Q moved to cleaned files folder
# cleaned_Q2_2017-07-19_10-Q moved to cleaned files folder
# cleaned_Q1_2018-04-18_10-Q moved to cleaned files folder
# cleaned_Q3_2017-10-18_10-Q moved to cleaned files folder
# cleaned_Q1_2017-04-20_10-Q moved to cleaned files folder
# cleaned_Q3_2016-10-20_10-Q moved to cleaned files folder
# cleaned_2017-01-27_10-K moved to cleaned files folder
# cleaned_Q2_2016-07-19_10-Q moved to cleaned files folder
# cleaned_Q1_2016-04-20_10-Q moved to cleaned files folder
# cleaned_Q2_2015-07-17_10-Q moved to cleaned files folder
# cleaned_Q3_2015-10-16_10-Q moved to cleaned files folder
# cleaned_2016-01-28_10-K moved to cleaned files folder
# cleaned_Q1_2015-04-17_10-Q moved to cleaned files folder
# cleaned_2015-01-29_10-K moved to cleaned files folder
# cleaned_Q2_2014-07-22_10-Q moved to cleaned files folder
# cleaned_Q3_2014-10-20_10-Q moved to cleaned files folder
# cleaned_Q1_2014-04-23_10-Q moved to cleaned files folder
# cleaned_2014-02-03_10-K moved to cleaned files folder
# ***Tesla, Inc***
# cleaned_Q2_2018-08-06_10-Q moved to cleaned files folder
# cleaned_2019-02-19_10-K moved to cleaned files folder
# cleaned_2018-02-23_10-K moved to cleaned files folder
# cleaned_Q3_2018-11-02_10-Q moved to cleaned files folder
# cleaned_Q2_2017-08-04_10-Q moved to cleaned files folder
# cleaned_Q1_2018-05-07_10-Q moved to cleaned files folder
# cleaned_Q3_2017-11-03_10-Q moved to cleaned files folder
# cleaned_Q1_2017-05-10_10-Q moved to cleaned files folder
# cleaned_2017-03-01_10-K moved to cleaned files folder
# ***Facebook Inc***
# cleaned_Q2_2018-07-26_10-Q moved to cleaned files folder
# cleaned_2019-01-31_10-K moved to cleaned files folder
# cleaned_2018-02-01_10-K moved to cleaned files folder
# cleaned_Q3_2018-10-31_10-Q moved to cleaned files folder
# cleaned_Q2_2017-07-27_10-Q moved to cleaned files folder
# cleaned_Q1_2018-04-26_10-Q moved to cleaned files folder
# cleaned_Q3_2017-11-02_10-Q moved to cleaned files folder
# cleaned_Q1_2017-05-04_10-Q moved to cleaned files folder
# cleaned_Q3_2016-11-03_10-Q moved to cleaned files folder
# cleaned_2017-02-03_10-K moved to cleaned files folder
# cleaned_Q2_2016-07-28_10-Q moved to cleaned files folder
# cleaned_Q1_2016-04-28_10-Q moved to cleaned files folder
# cleaned_Q2_2015-07-31_10-Q moved to cleaned files folder
# cleaned_Q3_2015-11-05_10-Q moved to cleaned files folder
# cleaned_2016-01-28_10-K moved to cleaned files folder
# cleaned_Q1_2015-04-23_10-Q moved to cleaned files folder
# cleaned_2015-01-29_10-K moved to cleaned files folder
# cleaned_Q2_2014-07-24_10-Q moved to cleaned files folder
# cleaned_Q3_2014-10-30_10-Q moved to cleaned files folder
# cleaned_Q1_2014-04-25_10-Q moved to cleaned files folder
# cleaned_2014-01-31_10-K moved to cleaned files folder
# ***JPMORGAN CHASE & CO***
# cleaned_Q2_2018-08-01_10-Q moved to cleaned files folder
# cleaned_2019-02-26_10-K moved to cleaned files folder
# cleaned_2018-02-27_10-K moved to cleaned files folder
# cleaned_Q3_2018-10-31_10-Q moved to cleaned files folder
# cleaned_Q2_2017-08-02_10-Q moved to cleaned files folder
# cleaned_Q1_2018-05-02_10-Q moved to cleaned files folder
# cleaned_Q3_2017-11-01_10-Q moved to cleaned files folder
# cleaned_Q1_2017-05-02_10-Q moved to cleaned files folder
# cleaned_Q3_2016-11-01_10-Q moved to cleaned files folder
# cleaned_2017-02-28_10-K moved to cleaned files folder
# cleaned_Q2_2016-08-03_10-Q moved to cleaned files folder
# cleaned_Q2_2015-08-03_10-Q moved to cleaned files folder
# cleaned_Q3_2015-11-02_10-Q moved to cleaned files folder
# cleaned_2016-02-23_10-K moved to cleaned files folder
# cleaned_Q1_2015-05-05_10-Q moved to cleaned files folder
# cleaned_2015-02-24_10-K moved to cleaned files folder
# cleaned_Q2_2014-08-04_10-Q moved to cleaned files folder
# cleaned_Q3_2014-11-03_10-Q moved to cleaned files folder
# cleaned_Q1_2014-05-02_10-Q moved to cleaned files folder
# cleaned_2014-02-20_10-K moved to cleaned files folder
# ***JOHNSON & JOHNSON***
# cleaned_Q2_2018-08-02_10-Q moved to cleaned files folder
# cleaned_2019-02-20_10-K moved to cleaned files folder
# cleaned_2018-02-21_10-K moved to cleaned files folder
# cleaned_Q3_2018-10-31_10-Q moved to cleaned files folder
# cleaned_Q2_2017-08-03_10-Q moved to cleaned files folder
# cleaned_Q1_2018-05-01_10-Q moved to cleaned files folder
# cleaned_Q3_2017-11-02_10-Q moved to cleaned files folder
# cleaned_Q1_2017-05-08_10-Q moved to cleaned files folder
# cleaned_Q3_2016-11-04_10-Q moved to cleaned files folder
# cleaned_2017-02-27_10-K moved to cleaned files folder
# cleaned_Q2_2016-08-04_10-Q moved to cleaned files folder
# cleaned_Q1_2016-05-10_10-Q moved to cleaned files folder
# cleaned_Q2_2015-07-31_10-Q moved to cleaned files folder
# cleaned_Q3_2015-10-30_10-Q moved to cleaned files folder
# cleaned_2016-02-24_10-K moved to cleaned files folder
# cleaned_Q1_2015-05-01_10-Q moved to cleaned files folder
# cleaned_2015-02-24_10-K moved to cleaned files folder
# cleaned_Q2_2014-08-01_10-Q moved to cleaned files folder
# cleaned_Q3_2014-10-30_10-Q moved to cleaned files folder
# cleaned_Q1_2014-05-02_10-Q moved to cleaned files folder
# cleaned_2014-02-21_10-K moved to cleaned files folder
# ***APPLE INC***
# cleaned_Q2_2018-08-01_10-Q moved to cleaned files folder
# cleaned_Q1_2019-01-30_10-Q moved to cleaned files folder
# cleaned_Q1_2018-02-02_10-Q moved to cleaned files folder
# cleaned_2018-11-05_10-K moved to cleaned files folder
# cleaned_Q2_2017-08-02_10-Q moved to cleaned files folder
# cleaned_Q1_2018-05-02_10-Q moved to cleaned files folder
# cleaned_2017-11-03_10-K moved to cleaned files folder
# cleaned_Q1_2017-05-03_10-Q moved to cleaned files folder
# cleaned_2016-10-26_10-K moved to cleaned files folder
# cleaned_Q1_2017-02-01_10-Q moved to cleaned files folder
# cleaned_Q2_2016-07-27_10-Q moved to cleaned files folder
# cleaned_Q1_2016-04-27_10-Q moved to cleaned files folder
# cleaned_Q2_2015-07-22_10-Q moved to cleaned files folder
# cleaned_2015-10-28_10-K moved to cleaned files folder
# cleaned_Q1_2016-01-27_10-Q moved to cleaned files folder
# cleaned_Q1_2015-04-28_10-Q moved to cleaned files folder
# cleaned_Q1_2015-01-28_10-Q moved to cleaned files folder
# cleaned_Q2_2014-07-23_10-Q moved to cleaned files folder
# cleaned_2014-10-27_10-K moved to cleaned files folder
# cleaned_Q1_2014-04-24_10-Q moved to cleaned files folder
# cleaned_Q1_2014-01-28_10-Q moved to cleaned files folder
# ***EXXON MOBIL CORP***
# cleaned_Q2_2018-08-02_10-Q moved to cleaned files folder
# cleaned_2019-02-27_10-K moved to cleaned files folder
# cleaned_2018-02-28_10-K moved to cleaned files folder
# cleaned_Q3_2018-11-07_10-Q moved to cleaned files folder
# cleaned_Q2_2017-08-02_10-Q moved to cleaned files folder
# cleaned_Q1_2018-05-03_10-Q moved to cleaned files folder
# cleaned_Q3_2017-11-01_10-Q moved to cleaned files folder
# cleaned_Q1_2017-05-03_10-Q moved to cleaned files folder
# cleaned_Q3_2016-11-03_10-Q moved to cleaned files folder
# cleaned_2017-02-22_10-K moved to cleaned files folder
# cleaned_Q2_2016-08-03_10-Q moved to cleaned files folder
# cleaned_Q1_2016-05-04_10-Q moved to cleaned files folder
# cleaned_Q2_2015-08-05_10-Q moved to cleaned files folder
# cleaned_Q3_2015-11-04_10-Q moved to cleaned files folder
# cleaned_2016-02-24_10-K moved to cleaned files folder
# cleaned_Q1_2015-05-06_10-Q moved to cleaned files folder
# cleaned_2015-02-25_10-K moved to cleaned files folder
# cleaned_Q2_2014-08-06_10-Q moved to cleaned files folder
# cleaned_Q3_2014-11-05_10-Q moved to cleaned files folder
# cleaned_Q1_2014-05-07_10-Q moved to cleaned files folder
# cleaned_2014-02-26_10-K moved to cleaned files folder
# ***AMERICAN EXPRESS CO***
# cleaned_Q2_2018-07-24_10-Q moved to cleaned files folder
# cleaned_2019-02-13_10-K moved to cleaned files folder
# cleaned_2018-02-16_10-K moved to cleaned files folder
# cleaned_Q3_2018-10-23_10-Q moved to cleaned files folder
# cleaned_Q2_2017-07-25_10-Q moved to cleaned files folder
# cleaned_Q1_2018-04-25_10-Q moved to cleaned files folder
# cleaned_Q3_2017-10-24_10-Q moved to cleaned files folder
# cleaned_Q1_2017-04-27_10-Q moved to cleaned files folder
# cleaned_Q3_2016-10-25_10-Q moved to cleaned files folder
# cleaned_2017-02-17_10-K moved to cleaned files folder
# cleaned_Q2_2016-07-26_10-Q moved to cleaned files folder
# cleaned_Q1_2016-04-27_10-Q moved to cleaned files folder
# cleaned_Q2_2015-07-29_10-Q moved to cleaned files folder
# cleaned_Q3_2015-10-28_10-Q moved to cleaned files folder
# cleaned_2016-02-19_10-K moved to cleaned files folder
# cleaned_Q1_2015-04-29_10-Q moved to cleaned files folder
# cleaned_2015-02-24_10-K moved to cleaned files folder
# cleaned_Q2_2014-07-30_10-Q moved to cleaned files folder
# cleaned_Q3_2014-10-28_10-Q moved to cleaned files folder
# cleaned_Q1_2014-04-29_10-Q moved to cleaned files folder
# cleaned_2014-02-25_10-K moved to cleaned files folder
# ***MICROSOFT CORP***
# cleaned_2018-08-03_10-K moved to cleaned files folder
# cleaned_Q1_2019-01-30_10-Q moved to cleaned files folder
# cleaned_Q1_2018-01-31_10-Q moved to cleaned files folder
# cleaned_Q3_2018-10-24_10-Q moved to cleaned files folder
# cleaned_2017-08-02_10-K moved to cleaned files folder
# cleaned_Q1_2018-04-26_10-Q moved to cleaned files folder
# cleaned_Q3_2017-10-26_10-Q moved to cleaned files folder
# cleaned_Q1_2017-04-27_10-Q moved to cleaned files folder
# cleaned_Q3_2016-10-20_10-Q moved to cleaned files folder
# cleaned_Q1_2017-01-26_10-Q moved to cleaned files folder
# cleaned_2016-07-28_10-K moved to cleaned files folder
# cleaned_Q1_2016-04-21_10-Q moved to cleaned files folder
# cleaned_2015-07-31_10-K moved to cleaned files folder
# cleaned_Q3_2015-10-22_10-Q moved to cleaned files folder
# cleaned_Q1_2016-01-28_10-Q moved to cleaned files folder
# cleaned_Q1_2015-04-23_10-Q moved to cleaned files folder
# cleaned_Q1_2015-01-26_10-Q moved to cleaned files folder
# cleaned_2014-07-31_10-K moved to cleaned files folder
# cleaned_Q3_2014-10-23_10-Q moved to cleaned files folder
# cleaned_Q1_2014-04-24_10-Q moved to cleaned files folder
# cleaned_Q1_2014-01-23_10-Q moved to cleaned files folder
# ***TESLA MOTORS INC***
# cleaned_Q3_2016-11-02_10-Q moved to cleaned files folder
# cleaned_Q2_2016-08-05_10-Q moved to cleaned files folder
# cleaned_Q1_2016-05-10_10-Q moved to cleaned files folder
# cleaned_Q2_2015-08-07_10-Q moved to cleaned files folder
# cleaned_Q3_2015-11-05_10-Q moved to cleaned files folder
# cleaned_2016-02-24_10-K moved to cleaned files folder
# cleaned_Q1_2015-05-11_10-Q moved to cleaned files folder
# cleaned_2015-02-26_10-K moved to cleaned files folder
# cleaned_Q2_2014-08-08_10-Q moved to cleaned files folder
# cleaned_Q3_2014-11-07_10-Q moved to cleaned files folder
# cleaned_Q1_2014-05-09_10-Q moved to cleaned files folder
# cleaned_2014-02-26_10-K moved to cleaned files folder
